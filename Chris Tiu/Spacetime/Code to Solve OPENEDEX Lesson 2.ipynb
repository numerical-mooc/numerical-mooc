# %% [markdown]
# Using sympy evaluate the partial derivative with respect to x  of the following equation at x=2.2

# %% [markdown]
# [(cos(x))^2*(sin(x))^3]\[(4*x^5)*exp(x)]

# %%
import numpy as NPY
import sympy
from matplotlib import pyplot
# %matplotlib inline
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16
import math

# %%
from sympy import init_printing
init_printing()

# %%
x = sympy.symbols('x')

# %%
x
# Out:
# x

# %%
5*x
# Out:
# 5⋅x

# %%
Numerator= (sympy.cos(x)**2)*(sympy.sin(x)**3)
Denomenator= 4*(x**5)*sympy.exp(x) 
Equation=Numerator/Denomenator
Equation
# Out:
#  -x    3       2
# ℯ  ⋅sin (x)⋅cos (x)
# ───────────────────
#            5
#         4⋅x

# %%
Solution=Equation.diff(x)
Solution
# Out:
#    -x    4              -x    3       2         -x    2       3         -x
#   ℯ  ⋅sin (x)⋅cos(x)   ℯ  ⋅sin (x)⋅cos (x)   3⋅ℯ  ⋅sin (x)⋅cos (x)   5⋅ℯ  ⋅sin
# - ────────────────── - ─────────────────── + ───────────────────── - ─────────
#             5                     5                      5
#          2⋅x                   4⋅x                    4⋅x
#
# 3       2
#  (x)⋅cos (x)
# ────────────
#    6
# 4⋅x

# %%
from sympy.utilities.lambdify import lambdify

# %%
Solution_lamb= lambdify((x), Solution)
print("The value of Solution at x=2.2, is {}.".format(Solution_lamb(2.2)))
# Out:
# The value of Solution at x=2.2, is -0.00026648912670920613.
