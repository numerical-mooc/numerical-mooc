# %% [markdown]
# Content under Creative Commons Attribution license CC-BY 4.0, code under MIT license (c)2014 L.A. Barba, C.D. Cooper, G.F. Forsyth.

# %% [markdown]
# Same Laplace problem:
#
# \begin{equation}
#   \begin{gathered}
# p=0 \text{ at } x=0\\
# \frac{\partial p}{\partial x}=0 \text{ at }x=1\\
# p = 0 \text{ at }y = 0 \\
# p = \sin \left(  \frac{\frac{3}{2}\pi x}{L} \right) \text{ at } y = 1
#   \end{gathered}
# \end{equation}

# %%
import numpy
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %matplotlib inline

# %%
def L2_error(p, pn):
    return numpy.sqrt(numpy.sum((p - pn)**2))

# %%
def plot2D(x, y, p):
    '''Creates 3D projection plot with appropriate limits and viewing angle
    
    Parameters:
    ----------
    x: array of float
        nodal coordinates in x
    y: array of float
        nodal coordinates in y
    p: 2D array of float
        calculated potential field
    
    '''
    fig = plt.figure(figsize=(11,7), dpi=100)
    ax = fig.gca(projection='3d')
    X,Y = numpy.meshgrid(x,y)
    surf = ax.plot_surface(X,Y,p[:], rstride=1, cstride=1, cmap=cm.coolwarm,
            linewidth=0, antialiased=False)

    ax.set_xlim(0,x[-1])
    ax.set_ylim(0,y[-1])
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')
    ax.view_init(30,45)

# %%
def laplace2d_jacobi(p, y, dx, dy, l2_target):
    '''Solves the diffusion equation with forward-time, centered scheme
    
    Parameters:
    ----------
    p: 2D array of float
        Initial potential distribution
    y: array of float
        Nodal coordinates in y
    dx: float
        Mesh size
    dy: float
        Mesh size
    l2_target: float
        Error target
        
    Returns:
    -------
    p: 2D array of float
        Potential distribution after relaxation
    '''
    
    l2norm = 1
    pn = numpy.empty_like(p)
    iteration_count = 0

    while l2norm > l2_target:
        pn = p.copy()
        p[1:-1,1:-1] = .25 * (pn[1:-1,2:]+pn[1:-1,:-2]+pn[2:,1:-1]+pn[:-2,1:-1])
            
        #p[:,0] = 0
        #p[0,:] = 0
        #p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])
        p[:,-1] = p[:,-2]
        
        l2norm = numpy.sum(numpy.abs(p[1:-1,1:-1] - pn[1:-1,1:-1]))
        
        iteration_count += 1
     
    return p, iteration_count

# %%
nx = 128
ny = 128

L = 5.
H = 5.

x = numpy.linspace(0,L,nx)
y = numpy.linspace(0,H,ny)

dx = L/(nx-1)
dy = H/(ny-1)

p = numpy.zeros((ny, nx))

p[:,0] = 0
p[:,-1] = p[:,-2]
p[0,:] = 0
p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])

# %% [markdown]
# benchmark
#
# N = 32
# *  numpy: 50.8 µs
# *  numba: 1.16 ms
#
# N = 64
# *  numpy: 81.1 µs
# *  numba: 4.49 ms
#
# N = 128
# *  numpy: 190 µs
# *  numba: 18.5 ms
#
# N = 256
# *  numpy: 584 µs
# *  numba: 76.2 ms
#
# N = 512
# *  numpy: 4.54 ms
# *  numba: 296 ms

# %%
# %load_ext cythonmagic

# %%
# %%cython
# cimport numpy
# cimport cython
# ctypedef numpy.float_t FTYPE_t
#
# import numpy
#
# @cython.boundscheck(False)
# def laplace2d_jacobi_cython(numpy.ndarray[FTYPE_t, ndim=2] p,
#                             numpy.ndarray[FTYPE_t, ndim=1] y,
#                             double dx,
#                             double dy,
#                             int nx,
#                             int ny,
#                             double eps):
#     cdef int iterations, i, j
#     cdef double error
#     cdef numpy.ndarray[FTYPE_t, ndim=2] pn
#
#     iterations = 0
#     error = 2*eps
#
#     while error > eps:
#         pn = p.copy()
#         error = 0.0
#         for j in range(1,ny-1):
#             for i in range(1,nx-1):
#                 p[j,i] = .25 * (pn[j,i-1] + pn[j,i+1] + pn[j-1,i] + pn[j+1,i])
#                 error += abs(p[j,i] - pn[j,i])
#
#         for j in range(ny):
#             p[j,-1] = p[j,-2]
#         iterations += 1
#         #error /= float(nx*ny)
#
#     return p, iterations

# %%
import time

# %%
nx_vals = [32, 64, 128]

for nx in nx_vals:

    ny = nx

    L = 5.
    H = 5.

    x = numpy.linspace(0,L,nx)
    y = numpy.linspace(0,H,ny)

    dx = L/(nx-1)
    dy = H/(ny-1)

    p = numpy.zeros((ny, nx))

    p[:,0] = 0
    p[:,-1] = p[:,-2]
    p[0,:] = 0
    p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])
    
    t1c = time.time()
    pjaccyth, itercyth = laplace2d_jacobi_cython(p, y, dx, dy, nx, ny, 1e-8)
    t2c = time.time()
    #print t2-t1
    
    p = numpy.zeros((ny, nx))

    p[:,0] = 0
    p[:,-1] = p[:,-2]
    p[0,:] = 0
    p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])
    
    t1n = time.time()
    pjac, iternumpy = laplace2d_jacobi(p, y, dx, dy, 1e-8)
    t2n = time.time()
    #print t2-t1
    
    assert numpy.allclose(pjac, pjaccyth)
    
    print "Grid size: {}x{}    Numpy time: {} s for {} iterations\
            Cython time: {} s for {} iterations".format(nx, nx, t2n-t1n, iternumpy, t2c-t1c, itercyth)
# Out:
# Grid size: 32x32    Numpy time: 0.181106090546 s for 4533 iterations            Cython time: 0.0453939437866 s for 4533 iterations
# Grid size: 64x64    Numpy time: 1.26039910316 s for 17886 iterations            Cython time: 0.358603954315 s for 17886 iterations
# Grid size: 128x128    Numpy time: 13.1573009491 s for 69145 iterations            Cython time: 5.23908090591 s for 69145 iterations

# %%
plot2D(x,y,pjac)

# %% [markdown]
# ### Gauss Seidel

# %%
# %%cython
# cimport numpy
# cimport cython
# ctypedef numpy.float_t FTYPE_t
#
# import numpy
#
# @cython.boundscheck(False)
# def laplace2d_gauss_seidel_cython(numpy.ndarray[FTYPE_t, ndim=2] p,
#                             numpy.ndarray[FTYPE_t, ndim=1] y,
#                             double dx,
#                             double dy,
#                             int nx,
#                             int ny,
#                             double eps):
#     cdef int iterations, i, j
#     cdef double error
#     cdef numpy.ndarray[FTYPE_t, ndim=2] pn
#
#     iterations = 0
#     error = 2*eps
#
#     while error > eps:
#         pn = p.copy()
#         error = 0.0
#         for j in range(1,ny-1):
#             for i in range(1,nx-1):
#                 p[j,i] = .25 * (p[j,i-1] + p[j,i+1] + p[j-1,i] + p[j+1,i])
#                 error += abs(p[j,i] - pn[j,i])
#
#         for j in range(ny):
#             p[j,-1] = p[j,-2]
#         iterations += 1
#         #error /= float(nx*ny)
#
#     return p, iterations

# %%
nx_vals = [32, 64, 128]

for nx in nx_vals:

    ny = nx

    L = 5.
    H = 5.

    x = numpy.linspace(0,L,nx)
    y = numpy.linspace(0,H,ny)

    dx = L/(nx-1)
    dy = H/(ny-1)

    p = numpy.zeros((ny, nx))

    p[:,0] = 0
    p[:,-1] = p[:,-2]
    p[0,:] = 0
    p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])
    
    t1c = time.time()
    pjaccyth, itercyth = laplace2d_gauss_seidel_cython(p, y, dx, dy, nx, ny, 1e-8)
    t2c = time.time()
    
    print "Gauss Seidel: Grid size: {}x{}  Cython time: {} s for {} iterations".format(nx, nx, t2c-t1c, itercyth)
# Out:
# Gauss Seidel: Grid size: 32x32  Cython time: 0.0382339954376 s for 2176 iterations
# Gauss Seidel: Grid size: 64x64  Cython time: 0.279848814011 s for 8398 iterations
# Gauss Seidel: Grid size: 128x128  Cython time: 4.21140408516 s for 32023 iterations

# %% [markdown]
# ### SOR

# %% [markdown]
# $$p^{n+1}_{i,j} = (1 - \omega)p^n_{i,j} + \frac{\omega}{4} \left(p^n_{i,j-1} + p^n_{i,j+1} + p^n_{i-1,j} + p^n_{i+1,j} \right)$$

# %% [markdown]
# *  only convergent for $0 < \omega < 2$
# *  faster than Gauss-Seidel only if $1 < \omega < 2$
#
# $$\omega \approx \frac{2}{1+\frac{\pi}{nx}}$$
#
# for a square lattice
#
# cite: http://www.physics.buffalo.edu/phy410-505/2011/topic3/app1/index.html

# %% [markdown]
# if this has p = p below, it isn't easily parallelizable.  check how that affects timing
#
# blows up if it's p = p.  so SOR is the fastest but only in serial

# %%
# %%cython
# cimport numpy
# cimport cython
# ctypedef numpy.float_t FTYPE_t
#
# import numpy
#
# @cython.boundscheck(False)
# def laplace2d_SOR_cython(numpy.ndarray[FTYPE_t, ndim=2] p,
#                             numpy.ndarray[FTYPE_t, ndim=1] y,
#                             double dx,
#                             double dy,
#                             int nx,
#                             int ny,
#                             double eps,
#                             double omega):
#     cdef int iterations, i, j
#     cdef double error
#     cdef numpy.ndarray[FTYPE_t, ndim=2] pn
#
#     iterations = 0
#     error = 2*eps
#
#     while error > eps:
#         pn = p.copy()
#         error = 0.0
#         for j in range(1,ny-1):
#             for i in range(1,nx-1):
#                 p[j,i] = (1 - omega) * p[j,i] +\
#                 .25 * omega * (p[j,i-1] + p[j,i+1] + p[j-1,i] + p[j+1,i])
#                 error += abs(p[j,i] - pn[j,i])
#
#         for j in range(ny):
#             p[j,-1] = p[j,-2]
#         iterations += 1
#         #error /= float(nx*ny)
#
#     return p, iterations

# %% [markdown]
# ### Check that with $\omega=1$ this is same as Gauss Seidel

# %%
nx_vals = [32, 64, 128]

omega = 1.

for nx in nx_vals:

    ny = nx

    L = 5.
    H = 5.

    x = numpy.linspace(0,L,nx)
    y = numpy.linspace(0,H,ny)

    dx = L/(nx-1)
    dy = H/(ny-1)

    p = numpy.zeros((ny, nx))

    p[:,0] = 0
    p[:,-1] = p[:,-2]
    p[0,:] = 0
    p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])
    
    t1c = time.time()
    pjaccyth, itercyth = laplace2d_SOR_cython(p, y, dx, dy, nx, ny, 1e-8, omega)
    t2c = time.time()
    
    print "SOR: Grid size: {}x{}  Cython time: {} s for {} iterations".format(nx, nx, t2c-t1c, itercyth)
# Out:
# SOR: Grid size: 32x32  Cython time: 0.028028011322 s for 2176 iterations
# SOR: Grid size: 64x64  Cython time: 0.325101137161 s for 8398 iterations
# SOR: Grid size: 128x128  Cython time: 4.66308522224 s for 32023 iterations

# %% [markdown]
# ### Now with $\omega = 1.5$

# %%
nx_vals = [32, 64, 128]

omega = 1.5

for nx in nx_vals:

    ny = nx

    L = 5.
    H = 5.

    x = numpy.linspace(0,L,nx)
    y = numpy.linspace(0,H,ny)

    dx = L/(nx-1)
    dy = H/(ny-1)

    p = numpy.zeros((ny, nx))

    p[:,0] = 0
    p[:,-1] = p[:,-2]
    p[0,:] = 0
    p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])
    
    t1c = time.time()
    pjaccyth, itercyth = laplace2d_SOR_cython(p, y, dx, dy, nx, ny, 1e-8, omega)
    t2c = time.time()
    
    print "SOR: Grid size: {}x{}  Cython time: {} s for {} iterations".format(nx, nx, t2c-t1c, itercyth)
# Out:
# SOR: Grid size: 32x32  Cython time: 0.0127160549164 s for 903 iterations
# SOR: Grid size: 64x64  Cython time: 0.132938861847 s for 3522 iterations
# SOR: Grid size: 128x128  Cython time: 1.98641204834 s for 13579 iterations

# %%
plot2D(x,y,pjaccyth)

# %% [markdown]
# ### Now with tuned $\omega$

# %% [markdown]
# $$\omega \approx \frac{2}{1+\frac{\pi}{nx}}$$
#
# this is the fastest method available in serial

# %%
nx_vals = [32, 64, 128]

for nx in nx_vals:
    
    omega = 2. / (1 + numpy.pi/nx)
    
    ny = nx

    L = 5.
    H = 5.

    x = numpy.linspace(0,L,nx)
    y = numpy.linspace(0,H,ny)

    dx = L/(nx-1)
    dy = H/(ny-1)

    p = numpy.zeros((ny, nx))

    p[:,0] = 0
    p[:,-1] = p[:,-2]
    p[0,:] = 0
    p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])
    
    t1c = time.time()
    pjaccyth, itercyth = laplace2d_SOR_cython(p, y, dx, dy, nx, ny, 1e-8, omega)
    t2c = time.time()
    
    print "SOR: Grid size: {}x{}  Cython time: {} s for {} iterations".format(nx, nx, t2c-t1c, itercyth)
# Out:
# SOR: Grid size: 32x32  Cython time: 0.00316309928894 s for 321 iterations
# SOR: Grid size: 64x64  Cython time: 0.0270550251007 s for 688 iterations
# SOR: Grid size: 128x128  Cython time: 0.218158960342 s for 1448 iterations

# %%
plot2D(x,y,pjaccyth)

# %% [markdown]
# ### Scheduled relaxed Jacobi

# %%
# %%cython
# cimport numpy
# cimport cython
# ctypedef numpy.float_t FTYPE_t
#
# import numpy
#
# @cython.boundscheck(False)
# def laplace2d_SRJ_cython(numpy.ndarray[FTYPE_t, ndim=2] p,
#                             numpy.ndarray[FTYPE_t, ndim=1] y,
#                             numpy.ndarray[FTYPE_t, ndim=1] wt,
#                             double dx,
#                             double dy,
#                             int nx,
#                             int ny,
#                             double eps, ):
#     cdef int iterations, i, j
#     cdef double error
#     cdef numpy.ndarray[FTYPE_t, ndim=2] pn
#     cdef double omega
#
#     iterations = 0
#     error = 2*eps
#
#     while error > eps:
#         #for k, loopcount in enumerate(qs):
#             #omega = omegas[k]
#             #for l in range(loopcount):
#         for omega in wt:
#             iterations += 1
#
#             pn = p.copy()
#             error = 0.0
#             for j in range(1,ny-1):
#                 for i in range(1,nx-1):
#                     p[j,i] = (1 - omega) * pn[j,i] +\
#                     .25 * omega * (pn[j,i-1] + pn[j,i+1] + pn[j-1,i] + pn[j+1,i])
#                     error += abs(p[j,i] - pn[j,i])
#
#             for j in range(ny):
#                 p[j,-1] = p[j,-2]
#
#
#
#             if error <= eps:
#                 return p, iterations
#             #error /= float(nx*ny)
#
#     return p, iterations

# %%
nx_vals = [32, 64, 128]

for nx in nx_vals:

    ny = nx

    L = 5.
    H = 5.

    x = numpy.linspace(0,L,nx)
    y = numpy.linspace(0,H,ny)

    dx = L/(nx-1)
    dy = H/(ny-1)

    p = numpy.zeros((ny, nx))

    p[:,0] = 0
    p[:,-1] = p[:,-2]
    p[0,:] = 0
    p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])

    t1srj = time.time()
    w, q = srj.get_relaxation_vectors(5, nx)
    wt = srj.get_relaxation_schedule(w,q)
    
    pSRJ, iterations = laplace2d_SRJ_cython(p, y,wt, dx, dy, nx, ny, 1e-8)
    t2srj = time.time()

    print "SRJ: Grid size: {}x{}  Cython time: {} s for {} iterations".format(nx, nx, t2srj-t1srj, iterations)
# Out:
# SRJ: Grid size: 32x32  Cython time: 0.035453081131 s for 515 iterations
# SRJ: Grid size: 64x64  Cython time: 0.0593409538269 s for 1569 iterations
# SRJ: Grid size: 128x128  Cython time: 0.390057086945 s for 4193 iterations

# %% [markdown]
# Compare to regular jacobi!!  128x128 from ~70000 iterations -> 4200

# %%
plot2D(x,y,pSRJ)

# %% [markdown]
# ### SRJ with Numpy

# %%
def laplace2d_SRJ_numpy(p, y, dx, dy, l2_target):
    '''Solves the diffusion equation with forward-time, centered scheme
    
    Parameters:
    ----------
    p: 2D array of float
        Initial potential distribution
    y: array of float
        Nodal coordinates in y
    dx: float
        Mesh size
    dy: float
        Mesh size
    l2_target: float
        Error target
        
    Returns:
    -------
    p: 2D array of float
        Potential distribution after relaxation
    '''
    nx = len(y)
    
    w, q = srj.get_relaxation_vectors(5, nx)
    wt = srj.get_relaxation_schedule(w,q)
    
    l2norm = 1
    pn = numpy.empty_like(p)
    iteration_count = 0

    while l2norm > l2_target:
        for omega in wt:
            pn = p.copy()
            p[1:-1,1:-1] = (1 - omega) * pn[1:-1,1:-1] + .25 * omega * (pn[1:-1,2:]+pn[1:-1,:-2]+pn[2:,1:-1]+pn[:-2,1:-1])

            p[:,-1] = p[:,-2]

            l2norm = numpy.sum(numpy.abs(p[1:-1,1:-1] - pn[1:-1,1:-1]))

            iteration_count += 1
     
    return p, iteration_count

# %%
nx_vals = [32, 64, 128]

for nx in nx_vals:

    ny = nx

    L = 5.
    H = 5.

    x = numpy.linspace(0,L,nx)
    y = numpy.linspace(0,H,ny)

    dx = L/(nx-1)
    dy = H/(ny-1)

    p = numpy.zeros((ny, nx))

    p[:,0] = 0
    p[:,-1] = p[:,-2]
    p[0,:] = 0
    p[-1,:] = numpy.sin(1.5*numpy.pi*x/x[-1])

    t1srj = time.time()    
    pSRJ, iterations = laplace2d_SRJ_numpy(p, y, dx, dy, 1e-8)
    t2srj = time.time()

    print "SRJ: Grid size: {}x{}  Numpy time: {} s for {} iterations".format(nx, nx, t2srj-t1srj, iterations)
# Out:
# SRJ: Grid size: 32x32  Numpy time: 0.0551509857178 s for 532 iterations
# SRJ: Grid size: 64x64  Numpy time: 0.187971830368 s for 1580 iterations
# SRJ: Grid size: 128x128  Numpy time: 1.15829181671 s for 4459 iterations

# %%
wt.size
# Out:
# 1824

# %%
srj = SRJScheduler(size=128)

# %%
srj.get_relaxation_vectors(5, 512)
# Out:
# (array([  5.92260000e+04,   3.90056000e+03,   1.87530000e+02,
#           9.11940000e+00,   7.39050000e-01]),
#  array([   1,    6,   40,  277, 1500]))

# %%
w, q = srj.get_relaxation_vectors(5, 512)
wt = srj.get_relaxation_schedule(w,q)

# %%
numpy.where(wt==36.78)
# Out:
# (array([ 23,  58,  72,  86, 100, 113, 127, 140, 153, 166, 179, 192, 205,
#         218, 231, 244, 257]),)

# %%
from IPython.core.display import HTML
css_file = '../../styles/numericalmoocstyle.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
"""Robust Scheduler for the SRJ scheme

This code is adapted from the MATLAB version provided by the authors
in the reference paper "Acceleration of the Jacobi iterative method by
factors exceeding 100 using scheduled relaxation", 2014, JCP, 274, pp
695--708

"""
# NumPy
import numpy

class SRJScheduler(object):
    """Scheduler object"""

    def __init__(self, size=512):
        """Constructor.

        Parameters:
        
        size : int
            Mesh size to be used

        Notes:
        
        The mesh size is used to determine the minimum admissible
        wavenumbers on the grid. 

        """
        # store the mesh size and compute kappa_min
        self.size = size
        self.kmin = kmin = numpy.sin(numpy.pi/2/size)**2

        # use arange to generate the k array initially
        self.k = numpy.arange( kmin, 2.0, kmin )
        
    def set_size(self, size):
        """Set the size and associated kappa_min parameter"""
        self.size = size
        self.kmin = kmin = numpy.sin(numpy.pi/2/size)**2
        self.k = numpy.arange( kmin, 2.0, kmin )

    @classmethod
    def get_relaxation_vectors(self, p=5, size=None):
        """Return the relaxation parameter 'w' and frequency 'q' vectors"""
        if size is None:
            size = self.size
        
        if p == 5:
            if size == 32:
                w = numpy.array( [330.57, 82.172, 13.441, 2.2402, 0.60810] )
                q = numpy.array( [1, 2, 7, 20, 46], int )

            if size == 64:
                w = numpy.array( [1228.8, 220.14, 26.168, 3.1668, 0.63890] )
                q = numpy.array( [1, 3, 10, 38, 106], int )

            if size == 128:
                w = numpy.array( [4522.0, 580.86, 50.729, 4.5018, 0.67161] )
                q = numpy.array( [1, 3, 16, 73, 250], int )

            if size == 256:
                w = numpy.array( [16459, 1513.4, 97.832, 6.4111, 0.70531] )
                q = numpy.array( [1, 4, 26, 142, 605], int )

            # FIXME Verify that this is legal
            if size >= 512:
                w = numpy.array( [59226, 3900.56, 187.53, 9.1194, 0.73905] )
                q = numpy.array( [1, 6, 40, 277, 1500], int )

        elif p == 4:
            if size == 16:
                w = numpy.array( [80.154, 17.217, 2.6201, 0.62230] )
                q = numpy.array( [1, 2, 8, 20], int )
                
            if size == 32:
                w = numpy.array( [289.46, 40.791, 4.0877, 0.66277] )
                q = numpy.array( [1, 3, 14, 46], int )

            if size == 64:
                w = numpy.array( [1029.4, 95.007, 6.3913, 0.70513] )
                q = numpy.array( [1, 5, 26, 114], int )

            if size == 128:
                w = numpy.array( [3596.4, 217.80, 9.9666, 0.74755] )
                q = numpy.array( [1, 7, 50, 285], int )

            if size == 256:
                w = numpy.array( [12329, 492.05, 15.444, 0.78831] )
                q = numpy.array( [1, 9, 86, 664], int )

            if size >= 512:
                w = numpy.array( [41459, 1096.3, 23.730, 0.82597] )
                q = numpy.array( [1, 12, 155, 1650], int )

        elif p == 3:
            if size == 16:
                w = numpy.array( [64.66, 6.215, 0.7042] )
                q = numpy.array( [1, 5, 21], int)

            if size == 32:
                w = numpy.array( [213.8, 11.45, 0.7616] )
                q = numpy.array( [1, 7, 45], int )

            if size == 64:
                w = numpy.array( [684.3, 20.73, 0.8149] )
                q = numpy.array( [1, 11, 106], int )

            if size == 128:
                w = numpy.array( [2114, 36.78, 0.8611] )
                q = numpy.array( [1, 17, 252], int )
                
            if size == 256:
                w = numpy.array( [6319, 63.99, 0.8989] )
                q = numpy.array( [1, 27, 625], int )

            if size == 512:
                w = numpy.array( [18278, 109.2, 0.9282] )
                q = numpy.array( [1, 43, 1571], int )

            if size >= 1024:
                w = numpy.array( [51769.1, 184.31, 0.95025] )
                q = numpy.array( [1, 68, 3955], int )

        else:
            raise ValueError("P level %d not currently supported"%p)

        return w, q
                
    def get_relaxation_schedule(self, w, q, size=None, write2file=False):
        """Return the relaxation schedule for a chosen scheme

        Parameter:
        
        w : Array or list
            Input vector containing the distinct relaxation 
            factors in descending order

        q : Python iterable
            Iteration counts for each relaxation parameter

        size : int
            Optional argument to re-compute the mesh size 
            and associated parameters

        write2file : bool
            Flag to write the relaxation sequence to /tmp/wt.txt

        Returns:

        wt : numpy.ndarray (dim=1)
            Relaxation schedule for the chosen scheme.

        """
        # update mesh size if needed
        if size is not None:
            self.set_size(size)

        # convert the input w and q to numpy arrays
        w = numpy.asarray( w.copy() )
        q = numpy.asarray( q.copy() )

        k = self.k

        # compute the relaxation schedule
        m = numpy.sum(q)
        wt = numpy.zeros(m)
        g = numpy.ones(k.size)

        wt[0] = w[0]
        q[0] = q[0] - 1
        g = g * numpy.abs(1 - k*wt[0])
        
        # begin iterations
        counter = 1; totPerc = 100
        while( sum( q!=0 ) ):
            if ( sum( q==0 ) != 0 ):
                index = numpy.where( q==0 )[0]
                if index == 0:
                    w = w[1:]
                    q = q[1:]
                elif index == q.size-1:
                    w = w[:-1]
                    q = q[:-1]
                else:
                    w[index:-1] = w[index+1:]
                    w = w[:-1]
                    
                    q[index:-1] = q[index+1:]
                    q = q[:-1]
            
            ww = 1./k[ numpy.where( g == numpy.max(g) )[0] ]
            dis = numpy.abs(w - ww)
            index = numpy.where( dis==numpy.min(dis) )[0][0]
            wt[counter] = w[index]
            g = g*numpy.abs( 1 - k*wt[counter] )
            q[index] = q[index] - 1

            # increment counter
            counter += 1
            perc = numpy.sum(q)/wt.size
            
        # write the output to file
        if write2file:
            fname = '/tmp/wt.dat'
            print 'Writing scheduling sequence to %s'%fname
            self.write2file( wt, fname )

        # return the relaxation schedule
        return wt

    def write2file(self, data, filename):
        """Save the data to an ASCII txt file"""
        numpy.savetxt( filename, data )

def test_scheduler(p=3):
    """Simple test for the SRJScheduler 

    We use the input input provided by the authors in the MATLAB
    script for a P=3 scheme on a 16 X 16 grid

    """
    # the srj scheduler object. The data was generated using N=512 for
    # the Matlab script and we follow the same here as well.
    scheduler = SRJScheduler(size=512)
    
    w = numpy.array( [ 64.66, 6.215, 0.7042] )
    q = numpy.array( [1, 5, 21] )

    # get the relaxation schedule generated by this script
    wt = scheduler.get_relaxation_schedule(w, q)

    # compare with sample data
    #data = numpy.loadtxt('data/p316.dat')
    
    #assert( numpy.alltrue( data == wt ) )

#if __name__ == '__main__':
#    print 'Testing for P=3, N=16'
#    test_scheduler()
    #print 'OK'
