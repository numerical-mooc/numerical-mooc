# %%
## Class Activity as found on Piazza

# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
from matplotlib import animation
from JSAnimation.IPython_display import display_animation

#Task 1
def u_initial(nt,nx,dx):
    
    #Setting intial conditions
    x = numpy.linspace(0,4,nx)
    t = numpy
    u = numpy.zeros(nx)
    u[:(nx-1)/2] = 1;
    
    #plt.figure(figsize=(8,6))
    #plt.plot(x,u)
    #plt.ylim(0,2)
    
    
    return (u,x)

#u_initial();

# %% [markdown]
# #Task2
#
# "computeF = lambda u: (u/2)**2" will define the function u inline and allow the user to call computeF as a function, for example, computeF(4) >> 4

# %%
computeF = lambda u: (u/2)**2

## Task 3

def maccormack(u, nt, dt, dx):
    un = numpy.zeros((nt,len(u)))
    un[:] = u.copy()
    ustar = u.copy()
    
    for n in range(1,nt):
        F = computeF(u)
        
        
        ustar[:-1] = un[n-1][:-1]-(dt/dx)*(F[1:]-F[:-1])
        
        Fstar = computeF(ustar)
        
        un[n][1:] = .5*(un[n-1][1:] + ustar[1:] - (dx/dt)*(Fstar[1:]-Fstar[:-1]))
        
        u = un[n].copy()
        
    return un

nx = 81
nt = 70
dx = 4.0/(nx-1)
(u0,x)=u_initial(nt,nx,dx);
sol=maccormack(u0,nx,nt,dx);
#plt.figure(figsize=(8,6))
#plt.plot(x,sol);
# Out:
# /home/gil/anaconda3/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: RuntimeWarning: overflow encountered in square
#   if __name__ == '__main__':
# /home/gil/anaconda3/lib/python3.4/site-packages/IPython/kernel/__main__.py:14: RuntimeWarning: invalid value encountered in subtract
# /home/gil/anaconda3/lib/python3.4/site-packages/IPython/kernel/__main__.py:18: RuntimeWarning: invalid value encountered in subtract

# %%
def animate(data):
    x = numpy.linspace(0,4,nx)
    y = data
    line.set_data(x,y)
    return line,



u0,x = u_initial(nt,nx,dx)
sigma = 1
dt = sigma*dx
un = maccormack(u0,nt,dt,dx)

fig = plt.figure();
ax = plt.axes(xlim=(0,4),ylim=(-.5,2));
line, = ax.plot([],[],lw=2);

anim = animation.FuncAnimation(fig, animate, frames=un, interval=50)
display_animation(anim, default_mode='once')
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %%
## Task 4
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
from matplotlib import animation
from JSAnimation.IPython_display import display_animation
import warnings
warnings.filterwarnings('ignore')

def u_initial2(nt,nx,dx):
    
    #Setting intial conditions
    x = numpy.linspace(0,4,nx)
    t = numpy
    u = numpy.zeros(nx)
    u[:(nx-1)/2] = 1;
    
    #plt.figure(figsize=(8,6))
    #plt.plot(x,u)
    #plt.ylim(0,2)
    
    
    return (u,x)

computeF2 = lambda u: (u/2)**2

def maccormack2(u, nt, dt, dx):
    un = numpy.zeros((nt,len(u)))
    un[:] = u.copy()
    ustar = u.copy()
    
    for n in range(1,nt):
        F = computeF2(u)
        
        
        ustar[:-1] = un[n-1][:-1]-(dt/dx)*(F[1:]-F[:-1]) + 0.4*(un[n-1][1:]+un[n-1][:-1]-2*un[n-1][:-1])
        
        Fstar = computeF2(ustar)
        
        un[n][1:] = .5*(un[n-1][1:] + ustar[1:] - (dx/dt)*(Fstar[1:]-Fstar[:-1]))
        
        u = un[n].copy()
        
    return un

nx = 81
nt = 250
dx = 4.0/(nx-1)
(u0,x)=u_initial2(nt,nx,dx);
sol=maccormack2(u0,nx,nt,dx);
#plt.figure(figsize=(8,6))
#plt.plot(x,sol);

def animate(data):
    x = numpy.linspace(0,4,nx)
    y = data
    line.set_data(x,y)
    return line,



u0,x = u_initial2(nt,nx,dx)
sigma = 1
dt = sigma*dx
un = maccormack2(u0,nt,dt,dx)

fig = plt.figure();
ax = plt.axes(xlim=(0,4),ylim=(-.5,2));
line, = ax.plot([],[],lw=2);

anim = animation.FuncAnimation(fig, animate, frames=un, interval=50)
display_animation(anim, default_mode='loop')
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...
