# %% [markdown]
# # Notes - Part 1
# Followed along and re-derived phugoid motion equations. Agreed with the derivation. Going to attempt with drag considerations in later...

# %%
# Running phygoid.py black box
# %run phugoid.py
#%matplotlib inline

# zt = 64, z = 16, theta = 0
plot_flight_path(64,16,0)

# %% [markdown]
# # Interesting Flight Paths

# %%
# Instructor Driven:
plot_flight_path(64,16,numpy.pi)

# Experimental:
plot_flight_path(64,16,10)

# %%
# Instructor Driven - Quarter Circle:
plot_flight_path(16,48,0.)

# Experimental - Halve instructor values...should yield same graph:
plot_flight_path(8,24,0.)

# %%
# Instructor Driven - Semi Circle
plot_flight_path(64,16,-numpy.pi/2)

# Experimental - multiply Instructor values via -1
plot_flight_path(-64,-16,numpy.pi/2)

# %% [markdown]
# # Closing Remarks
# Experiments went as expected.
