# %%
# Running phugiod script...kind of a black box for now
# Plotting it with matplotlib
# %run phugiod.py
# %matlibpolt inline
# Out:
# ERROR: File `'phugiod.py'` not found.
# ERROR: Line magic function `%matlibpolt` not found.
